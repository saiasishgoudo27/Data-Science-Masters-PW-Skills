# %%
go to google_collab and see my outputs
url -----------> "https://colab.research.google.com/drive/1kktTo0fTIbt9GVM5wHRSnypfslCRoPaO?authuser=0#scrollTo=Avz8OhTTnXdJ"

# %%
""" Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
scatter plot for age and fare columns in the titanic dataset. """

import seaborn as sns
import plotly.express as px
data_titanic = sns.load_dataset("titanic")
data_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
res = px.scatter(data_titanic, x = "age" , y = "fare") 
res.show()

# %%
"Q2.Using the tips dataset in the Plotly library, plot a box plot using Plotly express."
import seaborn as sns
import plotly.express as px
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
res = px.box(tips , x = "size", y = "tip")
res.show()

# %%
"Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= 'sex' and y= 'total_bill' column in the tips dataset. Also, use the 'smoker' column with the pattern_shape parameter and the 'day'column with the color parameter"
import seaborn as sns
import plotly.express as px
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
res = px.histogram(data , x = "sex", y = "total_bill", pattern_shape = "smoker",color = "day")
res.show()

# %%
"Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the 'species' column for the color parameter. Note: Use 'sepal_length', 'sepal_width', 'petal_length', 'petal_width' columns only with the dimensions parameter."
import seaborn as sns
import plotly.express as px
data_iris = sns.load_dataset("iris")
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
res = px.scatter_matrix(data_iris , color = "species",dimensions = ["sepal_length","sepal_width","petal_length","petal_width"])
res.show()

# %%
"Q5. What is Distplot? Using Plotly express, plot a distplot."
Ans:
    In Plotly Express, the distplot function is used to create a distribution plot, which provides a visual representation of the
    distribution of a single numerical variable.It combines a histogram with a kernel density estimate (KDE) curve.

# %%
import seaborn as sns
import plotly.express as px
data_iris = sns.load_dataset("iris")
sns.distplot(data_iris["petal_length"])
# Out:
# /tmp/ipykernel_2529/3522471288.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_iris["petal_length"])
# <AxesSubplot: xlabel='petal_length', ylabel='Density'>
